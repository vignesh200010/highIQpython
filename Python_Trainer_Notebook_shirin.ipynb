# %% [markdown]
# <a href="https://colab.research.google.com/github/RishubHighIQ/InstaBase_python_trainer/blob/main/Python_Trainer_Notebook_shirin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HighIQ Python Trainer Notebook** *(Zero to One)*

# %% [markdown]
# # [**Click on this Course**](https://www.youtube.com/watch?v=eWRfhZUzrAc&t=2s)

# %% [markdown]
# ## Variable And Functions

# %%
player_choice = 'rock'

# %% [markdown]
# ## Calling Funtions

# %% [markdown]
# # Dictionaries

# %% [markdown]
# ## User Input

# %% [markdown]
# ## Libraries, Lists, Methods

# %% [markdown]
# ## Function Arguments

# %% [markdown]
# ## If Statements

# %% [markdown]
# ## Concatenating Strings

# %% [markdown]
# ## f-strings

# %% [markdown]
# ## Else and Elif Statements

# %% [markdown]
# ## Refactoring and Nested If

# %% [markdown]
# ## Accessing Dictionary Values

# %% [markdown]
# ## Testing Game

# %% [markdown]
# ## Variables

# %% [markdown]
# ## Expressions and Statements

# %% [markdown]
# ## Comments

# %% [markdown]
# ## Data Types

# %% [markdown]
# ## Operators

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# ## Boolean Operators

# %% [markdown]
# ## Bitwise Operators

# %% [markdown]
# ## is & in Operators

# %% [markdown]
# ## Ternary Operator

# %% [markdown]
# ## Strings

# %% [markdown]
# ## String Methods

# %% [markdown]
# ## Escaping Characters

# %% [markdown]
# ## String Characters & Slicing

# %% [markdown]
# ## Booleans

# %% [markdown]
# ## Number Data Types

# %% [markdown]
# ## Built-in Functions

# %% [markdown]
# ## Enums

# %% [markdown]
# ## User Input

# %% [markdown]
# ## Control Statements

# %% [markdown]
# ## Lists

# %% [markdown]
# ## Sorting Lists

# %% [markdown]
# ## Tuples

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# ## Sets

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Variable Scope

# %% [markdown]
# ## Nested Functions

# %% [markdown]
# ## Closures

# %% [markdown]
# ## Objects

# %% [markdown]
# ## Loops

# %% [markdown]
# ## Break and Continue

# %% [markdown]
# ## Classes

# %% [markdown]
# ## Modules

# %% [markdown]
# ## Arguments from Command Line

# %% [markdown]
# ## Lambda Functions

# %% [markdown]
# ## Map, Filter, Reduce

# %% [markdown]
# ## Recursion

# %% [markdown]
# # The remaining modules from the Video is Optional if you wish to continue you can continue
